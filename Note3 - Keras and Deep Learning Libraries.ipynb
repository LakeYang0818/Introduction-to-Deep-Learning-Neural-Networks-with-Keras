# %% [markdown]
# # Keras and Deep Learning Libraries
#
# ## Deep Learning Libraries
#
# - Popular libraries: Tensorflow, PyTorch, Keras
# - Differences:
#     - Tensorflow is the most popular deep learning libraray, developed by Google
#     - PyTorch is a cousin of the Lua-based Torch framework, and is a strong competitor to Tensorflow
#     - Keras is the easiest API to use and the go-to libararu for quick prototyping and fast development

# %% [markdown]
# ## Regression Models with Keras
#
# ### Example:
# ![Screenshot%202023-08-15%20at%2010.29.01.png](attachment:Screenshot%202023-08-15%20at%2010.29.01.png)

# %%
"""import keras
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()

n_cols = concrete_data.shape[1]

model.add(Dense(5, actiavtion = "relu", input_shape = (n_cols, )))
model.add(Dense(5, activation = "relu"))
model.add(Dense(1))

model.compile(optimizer = "adam", loss = "mean_squared_error")
model.fit(predictors, target)

predictions = model.predict(test_data)"""
# Out:
# 2023-08-15 10:30:53.268081: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 7
#       3 from keras.layers import Dense
#       5 model = Sequential()
# ----> 7 n_cols = concrete_data.shape[1]
#       9 model.add(Dense(5, actiavtion = "relu", input_shape = (n_cols, )))
#      10 model.add(Dense(5, activation = "relu"))
#
# NameError: name 'concrete_data' is not defined

# %% [markdown]
# ## Classification Models with Keras
#
# #### Dataset
# ![Screenshot%202023-08-15%20at%2010.31.43.png](attachment:Screenshot%202023-08-15%20at%2010.31.43.png)

# %% [markdown]
# #### Predictions and Target
# ![Screenshot%202023-08-15%20at%2010.32.00.png](attachment:Screenshot%202023-08-15%20at%2010.32.00.png)

# %% [markdown]
# #### Model Structure:
# - change from 1 output node to 4 output nodes
# - Output type changes from numerical to categorical
# ![Screenshot%202023-08-15%20at%2010.32.27.png](attachment:Screenshot%202023-08-15%20at%2010.32.27.png)

# %% [markdown]
# #### Keras Code

# %%
"""import keras
from keras.models import Sequential
from keras.layers import Dense
from ketas.utils import to_categorical 

model = Sequential()

n_cols = car_data.shape[1]

target = to_categorical(target)

model.add(Dense(5, actiavtion = "relu", input_shape = (n_cols, )))
model.add(Dense(5, activation = "relu"))
model.add(Dense(4, activation = "softmax"))

model.compile(optimizer = "adam", 
              loss = "categorical_crossentropy", 
              metrics = ["accuracy"])
model.fit(predictors, target, epochs = 10)

predictions = model.predict(test_data)"""
# Out:
# 'import keras\nfrom keras.models import Sequential\nfrom keras.layers import Dense\nfrom ketas.utils import to_categorical \n\nmodel = Sequential()\n\nn_cols = car_data.shape[1]\n\ntarget = to_categorical(target)\n\nmodel.add(Dense(5, actiavtion = "relu", input_shape = (n_cols, )))\nmodel.add(Dense(5, activation = "relu"))\nmodel.add(Dense(4, activation = "softmax"))\n\nmodel.compile(optimizer = "adam", \n              loss = "categorical_crossentropy", \n              metrics = ["accuracy"])\nmodel.fit(predictors, target, epochs = 10)\n\npredictions = model.predict(test_data)'
