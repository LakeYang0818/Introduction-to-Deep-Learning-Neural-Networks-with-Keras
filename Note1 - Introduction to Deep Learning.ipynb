# %% [markdown]
# # Introduction to Deep Learning
#
# ## Applications
# 1. Color Restoration
#     - Automatic colorization and color restoration in clack and white images
# 2. Speech Reenactment
#     - Synching lip movements in a video with an audio clip
#     - From audio to video
# 3. Automatic Handwriting Generation
# 4. Automatic Machine Translation
# 5. Automatically Adding Sounds to Silent Movies
# 6. Object Classification and Detection in Images

# %% [markdown]
# ## Forward Propagation
# **Structure**:
# ![Screenshot%202023-08-13%20at%2014.56.44.png](attachment:Screenshot%202023-08-13%20at%2014.56.44.png)

# %% [markdown]
# **Example**:
# ![Screenshot%202023-08-13%20at%2014.57.03.png](attachment:Screenshot%202023-08-13%20at%2014.57.03.png)
